# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import os
import glob

# %%
'''
This cell  imports a list of high-speed streams observed by OMNI and compares them to a list of times when ARTEMIS is on the E-S line
'''

omni_hss = pd.read_csv('lists/filtered_hss_from_omni.txt', delim_whitespace=True, names=['year', 'dayofyear', 'hour', 'minute', 'Bz', 'RMS', 'Speed', 'Density', 'Temperature'])    # Import the list of HSS observed by OMNI
artemis_dates = pd.read_csv('../artemis-near-ESline.csv', header=0,  parse_dates=[0, 1]) # Import times when ARTEMIS was near the E-S line

omni_hss['datetime'] = pd.to_datetime(omni_hss['year'].astype(str)+'-'+omni_hss['dayofyear'].astype(str)+' '+omni_hss['hour'].astype(str).str.zfill(2)+':'+omni_hss['minute'].astype(str).str.zfill(2), format='%Y-%j %H:%M')   # Convert time columns to datetime objects
omni_hss.drop(columns=['year', 'dayofyear', 'hour', 'minute'], inplace=True)    # Drop unneeded columns now that we have datetime column

start_times = []    # Create empty array to store starting times for the HSS
stop_times = [] # Create empty array to store stopping times for the HSS
threshold = pd.Timedelta(minutes=180)   # HSS must be more than 180 minutes apart for them to be considered separate events
current_start = omni_hss['datetime'].iloc[0]    # Initialize the start of the first window for identifying overlapping ranges
prev_gap = pd.Timedelta(0)  # Initialize the time gap

# This loop goes through the list of HSSs and breaks them up into "events" which need to be at least 180 min apart
for i in range(1, len(omni_hss)):
    current_gap = omni_hss['datetime'].iloc[i] - omni_hss['datetime'].iloc[i - 1]   # Find the gap between the last timestamp and the current timestamp
    if current_gap > threshold and current_gap > prev_gap * 2:  # If this gap exceeds the threshold and is at least twice the size of the last gap (which should be on the order of minutes)
        start_times.append(current_start)   # Then create a new start time and append it to the array
        stop_times.append(omni_hss['datetime'].iloc[i - 1]) # Also take the last timestamp and add it as an end time to that array
        current_start = omni_hss['datetime'].iloc[i]  # Start a new group
    prev_gap = current_gap  # Reset the gap

start_times.append(current_start)   # Finally after the last iteration append the last value
stop_times.append(omni_hss['datetime'].iloc[-1])    # And do the same for the stop times.

# Create a DataFrame with start_times and stop_times
result = pd.DataFrame({'start_times': start_times, 'stop_times': stop_times})   # Create a new DataFrame based on these start and stop times from the loop

valid_starts = []   # Empty storage array to house the starts and stops in the DataFrame that are valid and overlap the ARTEMIS data
valid_stops = []    # Same as the valid_starts array but for stops

# This loop iterates through this list of starts and stops when ARTEMIS is on the E-S line and compares them to the intervals of HSSs
for astart, astop in zip(artemis_dates['Date_Start'], artemis_dates['Date_Stop']):
    for hstart, hstop in zip(result['start_times'], result['stop_times']):
        if (astart <= hstop) and (astop >= hstart): # Check if intervals overlap
            valid_start = max(astart, hstart)   # Find the latter of the two start times
            valid_stop = min(astop, hstop)  # Find the earlier of the two end times

            valid_starts.append(dt.datetime.strftime(valid_start, format='%Y-%m-%d %H:%M:%S'))
            valid_stops.append(dt.datetime.strftime(valid_stop, format='%Y-%m-%d %H:%M:%S'))

            fig, ax = plt.subplots(figsize=(15, 2))
            ax.barh(0.7, (hstop - hstart), left=hstart, height=0.4, color='red', alpha=0.6, label='HSS Candidate')
            ax.barh(0.3, (astop - astart), left=astart, height=0.4, color='blue', alpha=0.6, label='ARTEMIS')

            ax.set_title(f'HSS on {dt.datetime.strftime(valid_start, format="%Y-%m-%d")}')
            ax.set_yticks([])  # Remove y-axis ticks since they're not meaningful
            ax.set_xlabel('Date and Time (UTC)')
            ax.grid(True, alpha=0.3)
            ax.legend(loc='upper left')

            # Format x-axis to show dates nicely
            #date_formatter = mdates.DateFormatter('%Y-%m-%d %H:%M')
            #ax.xaxis.set_major_formatter(date_formatter)

            ax.xaxis.set_major_locator(mdates.HourLocator(interval=6))
            ax.xaxis.set_major_formatter(mdates.DateFormatter('%m-%d %H:%M'))
            ax.xaxis.set_minor_locator(mdates.HourLocator(interval=1))
            #plt.gcf().autofmt_xdate()

            # Adjust layout to prevent date labels from being cut off
            plt.tight_layout()

            plt.savefig(f'lists/overlap_plots/event_{dt.datetime.strftime(valid_start, format="%Y-%m-%d")}.png', bbox_inches='tight', dpi=300)
            plt.close()

intervals = pd.DataFrame({'Artemis_HSS_start': valid_starts, 'Artemis_HSS_stop': valid_stops})  # Create a DataFrame with all the valid starts and stops
intervals.to_csv('lists/HSS_intervals_from_filtered_omni.csv', index=None) # Convert the dataframe to a CSV

# %%
'''
This cell looks through all the existing OMNI data in ../Ordinary Solar Wind/ and looks for a HSS. The process works like this:
-> Is Vx >= 450 km/s
    |-> If so, check the density is less than 3 particles/cm^3
        | -> If so, check the next point and repeat. When you reach the end, if the interval length is less than one hour don't save it, but if it is greater, save it.
'''
def check_hss_conditions(row):  #Check if a row meets HSS conditions
    return (abs(row['VX']) >= 450 and row['N'] <= 5)

# Define directories
omni_input_dir = "../Ordinary Solar Wind/omni"
artemis_input_dir = "../Ordinary Solar Wind/artemis"
base_output_dir = "candidate_solar_wind/from_ordinary_omni"
omni_output_dir = os.path.join(base_output_dir, "omni")
artemis_output_dir = os.path.join(base_output_dir, "artemis")

# Create output directories
os.makedirs(omni_output_dir, exist_ok=True)
os.makedirs(artemis_output_dir, exist_ok=True)

# Get all CSV files
omni_files = glob.glob(os.path.join(omni_input_dir, "omni_*.csv"))
artemis_files = glob.glob(os.path.join(artemis_input_dir, "artemis_*.csv"))

start_times = []
stop_times = []

# Process OMNI files first to get intervals
for file in omni_files:
    df = pd.read_csv(file)
    print(f"Opening OMNI file {file}")
    df['Time'] = pd.to_datetime(df['Time'])
    df['is_hss'] = df.apply(check_hss_conditions, axis=1)
    df['group'] = (df['is_hss'] != df['is_hss'].shift()).cumsum()

    for group_num in df[df['is_hss']]['group'].unique():
        hss_period = df[df['group'] == group_num]

        if not hss_period['is_hss'].iloc[0]:
            continue

        duration = (hss_period['Time'].max() - hss_period['Time'].min())

        if duration >= dt.timedelta(hours=1):
            start_time = hss_period['Time'].iloc[0]
            stop_time = hss_period['Time'].iloc[-1]

            start_times.append(start_time)
            stop_times.append(stop_time)

            # Save OMNI data
            output_filename = f"omni_{start_time.strftime('%Y-%m-%d_%H-%M')}.csv"
            output_path = os.path.join(omni_output_dir, output_filename)
            hss_period.drop(['is_hss', 'group'], axis=1).to_csv(output_path, index=False)

            print(f"Found HSS period: {start_time} to {stop_time}")
        else:
            print(f"Found no HSS periods...")

# Create intervals DataFrame
intervals = pd.DataFrame({
    'HSS_start': [dt.datetime.strftime(t, '%Y-%m-%d %H:%M:%S') for t in start_times],
    'HSS_stop': [dt.datetime.strftime(t, '%Y-%m-%d %H:%M:%S') for t in stop_times]
})
intervals.to_csv('lists/HSS_intervals_from_ordinary_omni.csv', index=False)

# Process ARTEMIS files and extract matching intervals
for file in artemis_files:
    df_artemis = pd.read_csv(file)
    print(f"Opening ARTEMIS file {file}")
    df_artemis['Time'] = pd.to_datetime(df_artemis['Time'])

    # For each HSS interval, extract matching ARTEMIS data
    for start, stop in zip(start_times, stop_times):
        mask = (df_artemis['Time'] >= start) & (df_artemis['Time'] <= stop)
        if mask.any():
            artemis_period = df_artemis[mask]

            # Save ARTEMIS data for this period
            output_filename = f"artemis_{start.strftime('%Y-%m-%d_%H-%M')}.csv"
            output_path = os.path.join(artemis_output_dir, output_filename)
            artemis_period.to_csv(output_path, index=False)
# Out:
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2012-12-12_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2016-12-28_00-00.csv
# Found HSS period: 2016-12-28 00:38:00 to 2016-12-28 11:30:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2013-06-07_00-00.csv
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2020-09-16_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2019-07-31_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2019-08-01 01:03:00 to 2019-08-01 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2014-08-24_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2022-08-26_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2019-11-26_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2019-12-25_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2013-11-02_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2013-10-04_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2019-06-02_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2014-04-28_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2017-12-17_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2017-12-17 20:05:00 to 2017-12-17 21:15:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2017-12-17 23:36:00 to 2017-12-18 00:48:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2017-12-18 10:13:00 to 2017-12-18 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2017-07-22_00-00.csv
# Found HSS period: 2017-07-22 00:30:00 to 2017-07-22 05:42:00
# Found HSS period: 2017-07-22 05:46:00 to 2017-07-22 08:11:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2017-07-22 10:04:00 to 2017-07-22 13:14:00
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2017-07-22 14:29:00 to 2017-07-23 11:58:00
# Found HSS period: 2017-07-23 12:01:00 to 2017-07-23 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2023-10-13_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2023-10-13 22:47:00 to 2023-10-15 04:40:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2014-10-23_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2013-02-09_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2013-05-09_00-00.csv
# Found HSS period: 2013-05-09 00:34:00 to 2013-05-09 22:50:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2020-02-22_00-00.csv
# Found HSS period: 2020-02-22 00:37:00 to 2020-02-22 06:02:00
# Found no HSS periods...
# Found HSS period: 2020-02-22 06:14:00 to 2020-02-23 03:36:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2021-05-10_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2021-05-12 19:19:00 to 2021-05-12 20:28:00
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2021-05-12 21:25:00 to 2021-05-12 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2014-07-26_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2023-09-14_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2023-09-15 10:08:00 to 2023-09-15 11:17:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2023-09-15 14:28:00 to 2023-09-15 16:01:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2023-05-18_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2023-05-20 13:43:00 to 2023-05-20 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2014-05-28_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2018-11-06_00-00.csv
# Found HSS period: 2018-11-06 00:41:00 to 2018-11-06 11:27:00
# Found HSS period: 2018-11-06 11:31:00 to 2018-11-06 16:16:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2018-11-08 08:59:00 to 2018-11-08 10:15:00
# Found no HSS periods...
# Found HSS period: 2018-11-08 10:29:00 to 2018-11-08 18:21:00
# Found HSS period: 2018-11-08 18:23:00 to 2018-11-08 20:15:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2018-11-08 21:44:00 to 2018-11-08 22:51:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2019-07-02_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2014-02-28_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2017-10-19_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2018-05-14_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2013-07-07_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2016-01-09_00-00.csv
# Found HSS period: 2016-01-09 00:34:00 to 2016-01-09 03:34:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2020-12-14_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2020-04-22_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2020-04-22 01:30:00 to 2020-04-22 03:58:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2020-04-22 07:41:00 to 2020-04-22 10:06:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2015-05-17_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2014-06-26_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2012-08-16_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2012-08-16 11:21:00 to 2012-08-16 13:10:00
# Found HSS period: 2012-08-16 15:27:00 to 2012-08-16 16:33:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2012-08-16 23:54:00 to 2012-08-17 03:56:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2017-03-27_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2017-03-28 00:23:00 to 2017-03-28 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2016-06-04_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2013-04-09_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2013-04-11 17:04:00 to 2013-04-11 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2021-11-04_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2021-11-04 10:48:00 to 2021-11-05 04:53:00
# Found HSS period: 2021-11-05 07:56:00 to 2021-11-05 12:28:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2021-11-05 14:49:00 to 2021-11-05 16:16:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2021-11-05 18:53:00 to 2021-11-05 21:17:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2015-11-11_00-00.csv
# Found HSS period: 2015-11-11 00:36:00 to 2015-11-12 19:00:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2022-12-22_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2022-12-23 01:25:00 to 2022-12-23 02:29:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2022-12-23 18:07:00 to 2022-12-24 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2016-02-07_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2017-08-21_00-00.csv
# Found HSS period: 2017-08-21 00:34:00 to 2017-08-21 21:45:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2017-08-21 22:34:00 to 2017-08-21 23:54:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2017-08-22 07:11:00 to 2017-08-22 15:33:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2018-04-15_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2023-04-19_00-00.csv
# Found HSS period: 2023-04-19 00:39:00 to 2023-04-19 09:41:00
# Found HSS period: 2023-04-19 09:44:00 to 2023-04-19 12:38:00
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2023-04-19 17:28:00 to 2023-04-19 20:11:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2019-03-06_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2019-03-06 12:45:00 to 2019-03-06 13:51:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2023-08-15_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2014-09-23_00-00.csv
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2016-04-06_00-00.csv
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2023-03-21_00-00.csv
# Found no HSS periods...
# Found HSS period: 2023-03-21 14:15:00 to 2023-03-22 19:56:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2021-10-05_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2013-09-04_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2013-09-04 08:02:00 to 2013-09-04 15:01:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2013-09-04 16:45:00 to 2013-09-04 19:36:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2013-09-05 06:34:00 to 2013-09-05 09:59:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2022-01-02_00-00.csv
# Found HSS period: 2022-01-02 00:34:00 to 2022-01-02 16:56:00
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2022-01-02 18:05:00 to 2022-01-02 21:46:00
# Found no HSS periods...
# Found HSS period: 2022-01-02 23:04:00 to 2022-01-03 00:16:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2022-01-03 02:35:00 to 2022-01-03 09:15:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2022-01-03 09:58:00 to 2022-01-03 12:33:00
# Found HSS period: 2022-01-03 12:41:00 to 2022-01-03 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2015-07-15_00-00.csv
# Found HSS period: 2015-07-15 00:38:00 to 2015-07-15 12:51:00
# Found HSS period: 2015-07-15 12:53:00 to 2015-07-16 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2021-01-12_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2021-02-11_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2020-10-16_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2014-03-30_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2012-06-18_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2012-06-18 16:32:00 to 2012-06-18 18:14:00
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2012-06-18 18:45:00 to 2012-06-18 20:01:00
# Found no HSS periods...
# Found HSS period: 2012-06-18 22:54:00 to 2012-06-19 07:48:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2020-06-20_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2022-06-28_00-00.csv
# Found HSS period: 2022-06-28 00:37:00 to 2022-06-28 03:53:00
# Found HSS period: 2022-06-28 03:57:00 to 2022-06-29 05:41:00
# Found HSS period: 2022-06-29 05:43:00 to 2022-06-29 06:46:00
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2022-06-29 07:22:00 to 2022-06-29 13:48:00
# Found no HSS periods...
# Found HSS period: 2022-06-29 13:56:00 to 2022-06-29 16:22:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2019-01-05_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2019-01-05 11:34:00 to 2019-01-06 00:04:00
# Found HSS period: 2019-01-06 00:06:00 to 2019-01-06 01:08:00
# Found HSS period: 2019-01-06 01:10:00 to 2019-01-06 04:27:00
# Found HSS period: 2019-01-06 04:32:00 to 2019-01-06 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2023-02-19_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2019-10-27_00-00.csv
# Found HSS period: 2019-10-27 00:38:00 to 2019-10-28 20:15:00
# Found HSS period: 2019-10-28 20:17:00 to 2019-10-28 21:43:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2018-01-16_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2013-03-11_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2018-02-15_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2023-06-17_00-00.csv
# Found HSS period: 2023-06-17 00:36:00 to 2023-06-18 06:18:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2015-06-15_00-00.csv
# Found HSS period: 2015-06-15 00:35:00 to 2015-06-16 00:22:00
# Found HSS period: 2015-06-16 00:26:00 to 2015-06-16 01:31:00
# Found no HSS periods...
# Found HSS period: 2015-06-16 02:10:00 to 2015-06-16 06:53:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2015-06-16 08:37:00 to 2015-06-16 15:53:00
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2015-06-16 16:06:00 to 2015-06-16 19:44:00
# Found HSS period: 2015-06-16 19:47:00 to 2015-06-16 21:16:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2015-06-17 05:54:00 to 2015-06-17 09:57:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2015-06-17 11:24:00 to 2015-06-17 13:54:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2015-06-17 15:41:00 to 2015-06-17 18:06:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2017-09-19_00-00.csv
# Found HSS period: 2017-09-19 00:41:00 to 2017-09-20 07:49:00
# Found HSS period: 2017-09-20 08:00:00 to 2017-09-20 11:30:00
# Found no HSS periods...
# Found HSS period: 2017-09-20 11:49:00 to 2017-09-20 13:04:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2012-07-18_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2012-07-18 02:36:00 to 2012-07-18 08:07:00
# Found HSS period: 2012-07-18 08:16:00 to 2012-07-18 11:25:00
# Found no HSS periods...
# Found HSS period: 2012-07-18 11:37:00 to 2012-07-18 13:00:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2020-07-20_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2022-01-31_00-00.csv
# Found HSS period: 2022-01-31 00:35:00 to 2022-01-31 04:12:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2022-01-31 05:14:00 to 2022-01-31 06:18:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2022-01-31 08:35:00 to 2022-01-31 12:54:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2022-01-31 14:18:00 to 2022-01-31 17:18:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2021-04-11_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2020-03-23_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2020-03-23 11:20:00 to 2020-03-23 12:34:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2020-03-23 17:24:00 to 2020-03-23 18:58:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2020-03-23 20:06:00 to 2020-03-23 22:54:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2020-03-24 01:32:00 to 2020-03-24 08:10:00
# Found HSS period: 2020-03-24 08:14:00 to 2020-03-24 12:25:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2015-01-20_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2016-07-03_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2016-05-06_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2014-12-21_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2023-11-12_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2023-11-12 04:00:00 to 2023-11-12 06:01:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2017-06-23_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2022-03-01_00-00.csv
# Found HSS period: 2022-03-01 00:33:00 to 2022-03-01 05:19:00
# Found HSS period: 2022-03-01 06:03:00 to 2022-03-02 14:59:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2015-09-12_00-00.csv
# Found HSS period: 2015-09-12 00:35:00 to 2015-09-13 04:48:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2016-08-31_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2016-09-02 03:05:00 to 2016-09-02 07:15:00
# Found no HSS periods...
# Found HSS period: 2016-09-02 07:38:00 to 2016-09-02 11:06:00
# Found HSS period: 2016-09-02 11:09:00 to 2016-09-02 13:18:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2016-09-02 13:53:00 to 2016-09-02 15:14:00
# Found no HSS periods...
# Found HSS period: 2016-09-02 15:25:00 to 2016-09-02 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2015-04-18_00-00.csv
# Found HSS period: 2015-04-18 00:38:00 to 2015-04-18 11:13:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2015-04-18 17:33:00 to 2015-04-19 04:27:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2012-11-13_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2012-11-14 22:38:00 to 2012-11-14 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2012-10-15_00-00.csv
# Found HSS period: 2012-10-15 00:37:00 to 2012-10-15 13:10:00
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2012-05-20_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2018-06-13_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2013-01-11_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2018-03-16_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2018-03-17 03:30:00 to 2018-03-17 08:57:00
# Found no HSS periods...
# Found HSS period: 2018-03-17 09:13:00 to 2018-03-17 16:27:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2018-03-17 22:49:00 to 2018-03-18 00:25:00
# Found HSS period: 2018-03-18 00:29:00 to 2018-03-18 12:30:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2018-03-18 22:41:00 to 2018-03-18 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2016-03-08_00-00.csv
# Found HSS period: 2016-03-08 00:33:00 to 2016-03-08 06:39:00
# Found HSS period: 2016-03-08 06:45:00 to 2016-03-08 10:34:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2016-03-08 11:47:00 to 2016-03-08 14:00:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2022-03-31_00-00.csv
# Found no HSS periods...
# Found HSS period: 2022-03-31 12:52:00 to 2022-03-31 13:52:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2022-03-31 17:40:00 to 2022-03-31 18:53:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2022-04-01 01:40:00 to 2022-04-01 06:01:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2022-04-01 08:39:00 to 2022-04-01 10:51:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2022-04-01 15:28:00 to 2022-04-01 16:28:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2022-04-01 20:44:00 to 2022-04-01 22:16:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2022-04-02 00:06:00 to 2022-04-02 01:46:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2022-04-02 03:36:00 to 2022-04-02 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2017-05-25_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2017-02-25_00-00.csv
# Found HSS period: 2017-02-25 00:38:00 to 2017-02-26 02:01:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2021-12-03_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2021-12-04 02:01:00 to 2021-12-04 03:24:00
# Found HSS period: 2021-12-04 03:33:00 to 2021-12-04 14:53:00
# Found no HSS periods...
# Found HSS period: 2021-12-04 16:33:00 to 2021-12-04 19:15:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2015-03-20_00-00.csv
# Found HSS period: 2015-03-20 00:37:00 to 2015-03-20 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2012-04-20_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2016-10-29_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2016-10-29 05:09:00 to 2016-10-29 06:27:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2016-10-29 11:13:00 to 2016-10-29 13:19:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2016-10-29 15:58:00 to 2016-10-31 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2016-08-02_00-00.csv
# Found no HSS periods...
# Found HSS period: 2016-08-03 13:15:00 to 2016-08-03 18:28:00
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2016-08-03 18:43:00 to 2016-08-03 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2019-09-28_00-00.csv
# Found HSS period: 2019-09-28 00:30:00 to 2019-09-29 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2021-08-07_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2015-02-18_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2017-04-25_00-00.csv
# Found HSS period: 2017-04-25 00:31:00 to 2017-04-27 09:05:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2023-01-21_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2023-01-21 09:55:00 to 2023-01-21 19:27:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2014-11-21_00-00.csv
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2015-12-10_00-00.csv
# ...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2021-07-09_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2018-12-06_00-00.csv
# Found HSS period: 2018-12-07 18:00:00 to 2018-12-07 19:19:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2018-12-08 04:00:00 to 2018-12-08 17:21:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2018-12-08 18:26:00 to 2018-12-08 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2019-05-04_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2019-05-04 12:46:00 to 2019-05-04 14:43:00
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2019-05-04 15:06:00 to 2019-05-05 02:27:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2019-05-05 03:43:00 to 2019-05-05 05:42:00
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2016-09-30_00-00.csv
# Found HSS period: 2016-09-30 00:40:00 to 2016-10-01 18:29:00
# Found HSS period: 2016-10-01 18:31:00 to 2016-10-01 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2015-08-13_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2022-09-25_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2020-08-18_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2018-08-10_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2022-10-24_00-00.csv
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2022-10-24 02:30:00 to 2022-10-25 00:54:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2013-08-06_00-00.csv
# Found HSS period: 2013-08-06 00:33:00 to 2013-08-06 08:05:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2013-08-06 11:20:00 to 2013-08-06 12:46:00
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found no HSS periods...
# Found HSS period: 2013-08-09 20:48:00 to 2013-08-09 23:59:00
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2020-11-14_00-00.csv
# Opening OMNI file ../Ordinary Solar Wind/omni/omni_2020-01-24_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2017-06-23_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2022-03-01_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2014-12-21_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2023-11-12_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2015-01-20_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2016-05-06_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2016-07-03_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2020-03-23_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2020-07-20_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2012-07-18_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2022-01-31_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2021-04-11_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2017-09-19_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2023-06-17_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2015-06-15_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2013-03-11_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2018-01-16_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2018-02-15_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2019-10-27_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2023-02-19_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2022-06-28_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2019-01-05_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2020-10-16_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2014-03-30_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2020-06-20_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2012-06-18_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2021-01-12_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2021-02-11_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2015-07-15_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2013-09-04_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2022-01-02_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2016-04-06_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2023-03-21_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2021-10-05_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2023-08-15_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2014-09-23_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2023-04-19_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2019-03-06_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2018-04-15_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2017-08-21_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2015-11-11_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2022-12-22_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2016-02-07_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2013-04-09_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2016-06-04_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2021-11-04_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2017-03-27_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2012-08-16_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2015-05-17_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2014-06-26_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2020-12-14_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2020-04-22_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2016-01-09_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2013-07-07_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2017-10-19_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2018-05-14_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2018-11-06_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2019-07-02_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2014-02-28_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2014-05-28_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2023-05-18_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2023-09-14_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2014-07-26_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2021-05-10_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2020-02-22_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2013-05-09_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2014-10-23_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2023-10-13_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2013-02-09_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2017-12-17_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2017-07-22_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2014-04-28_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2013-11-02_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2013-10-04_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2019-06-02_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2019-11-26_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2019-12-25_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2014-08-24_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2022-08-26_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2013-06-07_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2019-07-31_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2020-09-16_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2012-12-12_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2016-12-28_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2020-01-24_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2020-11-14_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2013-08-06_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2022-10-24_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2020-08-18_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2018-08-10_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2015-08-13_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2022-09-25_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2016-09-30_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2018-12-06_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2021-07-09_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2019-05-04_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2022-05-29_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2019-02-04_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2018-07-12_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2012-03-21_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2013-12-31_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2017-01-27_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2017-11-17_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2015-10-12_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2020-05-21_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2022-04-30_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2022-07-27_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2012-09-15_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2018-10-08_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2012-01-22_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2012-02-21_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2018-09-09_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2016-11-28_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2019-08-29_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2021-09-06_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2019-04-04_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2013-12-02_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2021-06-09_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2021-03-12_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2014-01-30_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2014-11-21_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2015-12-10_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2022-11-23_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2023-12-12_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2023-01-21_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2017-04-25_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2015-02-18_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2021-08-07_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2019-09-28_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2012-04-20_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2016-10-29_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2016-08-02_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2021-12-03_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2015-03-20_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2017-02-25_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2017-05-25_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2022-03-31_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2016-03-08_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2018-03-16_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2013-01-11_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2012-11-13_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2012-10-15_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2012-05-20_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2018-06-13_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2015-04-18_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2016-08-31_00-00.csv
# Opening ARTEMIS file ../Ordinary Solar Wind/artemis/artemis_2015-09-12_00-00.csv

# %%
'''
This cell calculates dB/B in a running one-hour window with centered windows
'''
variables = ['BY_GSM', 'BZ_GSM', 'VX', 'N']
labels = ['B_y', 'B_z', 'V_x', 'N']

input_dir = "candidate_solar_wind/final/omni/"
files = glob.glob(os.path.join(input_dir, "omni_*.csv"))

window_size = 60  # 60-minute window
half_window = window_size // 2  # 30 minutes on each side

for f in files:
    print(f"Processing {f}")
    omni = pd.read_csv(f, delimiter=',', header=0, parse_dates=True)
    n_windows = len(omni) - window_size + 1  # Total possible windows

    if n_windows >= 1:
        print(f'Computing {n_windows} windows...')
        for v, l in zip(variables, labels):
            data_rows = [np.nan] * half_window  # Pad start with NaN

            # Calculate centered windows
            for n in range(n_windows):
                o_slice = omni[v][n:n + window_size]  # Take a chunk of data 60 minutes long
                avg_o = np.mean(o_slice)
                deltaO = np.array([x - avg_o for x in o_slice])  # Convert to numpy array
                deltaO = np.array([x - avg_o for x in o_slice])  # Convert to numpy array
                deltaO_over_O = np.mean(np.abs(deltaO)) / np.abs(avg_o)
                data_rows.append(deltaO_over_O)

            # Pad end with NaN
            data_rows.extend([np.nan] * (half_window - 1))

            # Ensure the length matches the original dataframe
            assert len(data_rows) == len(omni)

            # Add the new column to the dataframe
            omni[f'delta{l}'] = data_rows

        # Save the updated dataframe back to the same file
        omni.to_csv(f, index=False)
        print(f"Saved updated file with new columns: {f}")
# Out:
# Processing candidate_solar_wind/final/omni/omni_2015-07-16_13-00.csv
# Computing 811 windows...
# Saved updated file with new columns: candidate_solar_wind/final/omni/omni_2015-07-16_13-00.csv
# Processing candidate_solar_wind/final/omni/omni_2014-01-02_21-00.csv
# Computing 1350 windows...
# Saved updated file with new columns: candidate_solar_wind/final/omni/omni_2014-01-02_21-00.csv
# Processing candidate_solar_wind/final/omni/omni_2017-02-26_00-00.csv
# Computing 330 windows...
# Saved updated file with new columns: candidate_solar_wind/final/omni/omni_2017-02-26_00-00.csv
# Processing candidate_solar_wind/final/omni/omni_2015-10-14_03-00.csv
# Computing 511 windows...
# Saved updated file with new columns: candidate_solar_wind/final/omni/omni_2015-10-14_03-00.csv
# Processing candidate_solar_wind/final/omni/omni_2015-11-12_01-00.csv
# Computing 1105 windows...
# Saved updated file with new columns: candidate_solar_wind/final/omni/omni_2015-11-12_01-00.csv
# Processing candidate_solar_wind/final/omni/omni_2022-03-02_15-00.csv
# Computing 510 windows...
# Saved updated file with new columns: candidate_solar_wind/final/omni/omni_2022-03-02_15-00.csv
# Processing candidate_solar_wind/final/omni/omni_2022-12-24_23-00.csv
# Computing 930 windows...
# Saved updated file with new columns: candidate_solar_wind/final/omni/omni_2022-12-24_23-00.csv
# Processing candidate_solar_wind/final/omni/omni_2016-10-30_16-00.csv
# Computing 1884 windows...
# Saved updated file with new columns: candidate_solar_wind/final/omni/omni_2016-10-30_16-00.csv
# Processing candidate_solar_wind/final/omni/omni_2017-03-29_00-00.csv
# Computing 1408 windows...
# Saved updated file with new columns: candidate_solar_wind/final/omni/omni_2017-03-29_00-00.csv
# Processing candidate_solar_wind/final/omni/omni_2018-10-10_08-00.csv
# Computing 683 windows...
# Saved updated file with new columns: candidate_solar_wind/final/omni/omni_2018-10-10_08-00.csv
# Processing candidate_solar_wind/final/omni/omni_2015-12-11_00-00.csv
# Computing 1884 windows...
# Saved updated file with new columns: candidate_solar_wind/final/omni/omni_2015-12-11_00-00.csv
# Processing candidate_solar_wind/final/omni/omni_2022-05-30_12-00.csv
# Computing 1226 windows...
# Saved updated file with new columns: candidate_solar_wind/final/omni/omni_2022-05-30_12-00.csv

# %%
input_dir = "candidate_solar_wind/final/omni/"
files = glob.glob(os.path.join(input_dir, "omni_*.csv"))

for f in files:
    omni = pd.read_csv(f, delimiter=',', header=0)
    omni = omni.drop(columns=['Unnamed: 0']).reset_index(drop=True)
    omni.to_csv(f, index=True)
